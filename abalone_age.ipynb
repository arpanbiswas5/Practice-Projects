# %%
import pandas as pd
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# downloaded the dataframe in the python notebook, have to change the sex column into float or int data type as its a string datatype. need to change the rings column into age as per question.

# %%
df['Age']=df['Rings']+1.5

# %% [markdown]
# converting rings column into age column by adding 1.5 to the rings column.

# %%
df.drop('Rings',axis=1,inplace=True)

# %% [markdown]
# now dropping the rings column as now we have age column.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %% [markdown]
# there are no null values present in the dataset

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Age               float64
# dtype: object

# %% [markdown]
# sex column is object datatype and others are float data type we need to encode the sex column

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %% [markdown]
# there are 3 unique values, male, female and infant.

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# there are 4177 rows and 9 columns present

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# here in column whole weight,viscera weight,shell weight slight skewness might be present.

# %%
sn.distplot(df['Whole weight'],bins=10)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %% [markdown]
# plot is skewed

# %%
sn.distplot(df['Viscera weight'],bins=10)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %% [markdown]
# plot is skewed

# %%
sn.distplot(df['Shell weight'],bins=10)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %% [markdown]
# plot is skewed

# %%
sn.distplot(df['Height'],bins=10)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %% [markdown]
# plot is skewed

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Age               1.114102
# dtype: float64

# %% [markdown]
# skewness is present in all the columns

# %%
df['Length'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
df['Diameter'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
df['Height'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
df['Whole weight'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
df['Shell weight'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
df.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# Length               AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Diameter          AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Height             AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Whole weight      AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Shucked weight    AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Viscera weight          AxesSubplot(0.125,0.125;0.133621x0.343182)
# Shell weight         AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Age                   AxesSubplot(0.44569,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# outliers are present in all the columns

# %%
sn.countplot(df.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# the sex column is balanced

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,10])
plt.title("comparison between height and age")
sn.scatterplot(df['Height'],df['Age']);

# %% [markdown]
# more the height more is the age.

# %%
plt.figure(figsize=[10,10])
plt.title("comparison between length and age")
sn.scatterplot(df['Length'],df['Age']);

# %% [markdown]
# more the length more is the age

# %%
plt.figure(figsize=[10,10])
plt.title("comparison between Diameter and age")
sn.scatterplot(df['Diameter'],df['Age']);

# %% [markdown]
# more the diameter more is age

# %%
plt.figure(figsize=[10,10])
plt.title("comparison between Diameter and age")
sn.scatterplot(df['Whole weight'],df['Age']);

# %% [markdown]
# age is more with increasing weight

# %%
plt.figure(figsize=[10,10])
plt.title("comparison between Diameter and age")
sn.scatterplot(df['Sex'],df['Age']);

# %% [markdown]
# comparatively 0 i.e male has more age than other genders.

# %%
sn.pairplot(df,hue='Sex')

# %% [markdown]
# if we see the age column and the relationship with others mostly all the columns are increasing with age. size is getting larger and bigger

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
LB = LabelEncoder()
df['Sex'] = LB.fit_transform(df['Sex'])

# %% [markdown]
# encoding the sex column into int datatype

# %%
df['Sex'].unique()
# Out:
# array([2, 0, 1])

# %% [markdown]
# 3 unique values 0,1,2 where 2 is male, 1 is infant and 0 is female

# %%
df['Sex'].value_counts()
# Out:
# 2    1528
# 1    1342
# 0    1307
# Name: Sex, dtype: int64

# %% [markdown]
# value counts of each unique value.

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %%
cor=df.corr()

# %%
plt.figure(figsize=[10,10])
sn.heatmap(cor,annot=True,linewidth=10,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# sex column has the least correlation with age and highest correlation is shell weight, length has high correlation with other columns as well.

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#          166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#          238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#          334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#          433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#          674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#          754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#         1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#         1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#         1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#         1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#         2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#         2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new.head()
df_new.shape
# Out:
# (4027, 9)

# %%
Data_loss=((4177-4027)/4177)*100
Data_loss # here  data  loss is less than 5%
# Out:
# 3.5910940866650707

# %% [markdown]
# removing outliers, as we can see the the data loss is less than 5% we can remove the outliers

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(df_new):
    vif=pd.DataFrame()
    vif["variables"]=df_new.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(df_new.values,i) for i in range(df_new.shape[1])]
    return(vif)

# %%
calc_vif(df_new)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.598356
# 1          Length  714.643355
# 2        Diameter  769.284179
# 3          Height   96.603427
# 4    Whole weight  451.803714
# 5  Shucked weight  123.704621
# 6  Viscera weight   66.519130
# 7    Shell weight   95.016476
# 8             Age   32.009831

# %% [markdown]
# here i have highest multicollinearity in diameter and length, i will be dropping length because it has high multicollinearity, has outliers, and correlation with other columns

# %%
#df_new.drop('Shucked weight',axis=1,inplace=True)
#df_new.drop('Sex',axis=1,inplace=True)
df_new.drop('Length',axis=1,inplace=True)

# %% [markdown]
# dropped length column as it had outliers, skewness and multicollinearity, and not dropping other columns as i checked by dropping other columns it gave low accuracy.

# %%
df_new.shape
# Out:
# (4027, 8)

# %% [markdown]
# after dropping the column shape is 4027 rows and 8 columns

# %%
calc_vif(df_new)
# Out:
#         variables  VIF FACTOR
# 0             Sex    2.583958
# 1        Diameter  106.267168
# 2          Height   94.834276
# 3    Whole weight  451.423263
# 4  Shucked weight  123.265415
# 5  Viscera weight   66.310914
# 6    Shell weight   93.122445
# 7             Age   31.847435

# %% [markdown]
# multicollinearity has gone down for every column

# %%
df_new.skew()
# Out:
# Sex              -0.094886
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Age               0.725464
# dtype: float64

# %% [markdown]
# diameter has skewness

# %%
x=df_new.iloc[:,0:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# separating data and target column.

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson') 
x=pt.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.skew()
# Out:
# 0   -0.174523
# 1   -0.080956
# 2   -0.015962
# 3   -0.016797
# 4    0.021815
# 5    0.035902
# 6    0.016660
# dtype: float64

# %% [markdown]
# removed skewness from the column

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
x=pd.DataFrame(x)
x
# Out:
#              0         1         2         3         4         5         6
# 0     1.134329 -0.543379 -1.158933 -0.575135 -0.540865 -0.688032 -0.586354
# 1     1.134329 -1.401132 -1.280406 -1.354050 -1.311318 -1.332854 -1.332717
# 2    -1.313068  0.037163 -0.128305 -0.184498 -0.362705 -0.240373 -0.080214
# 3     1.134329 -0.543379 -0.395963 -0.570150 -0.592261 -0.539936 -0.542533
# 4    -0.008746 -1.474343 -1.518600 -1.414577 -1.378735 -1.451548 -1.482926
# ...        ...       ...       ...       ...       ...       ...       ...
# 4022 -1.313068  0.390420  0.716250  0.277874  0.217107  0.690782  0.227258
# 4023  1.134329  0.269661 -0.128305  0.441584  0.534924  0.474179  0.314936
# 4024  1.134329  0.705921  1.943633  0.853434  0.901897  1.089651  0.663632
# 4025 -1.313068  0.837713  0.286070  0.697385  0.924153  0.876428  0.577520
# 4026  1.134329  1.855505  1.625584  2.145775  2.314466  1.732146  1.856755
#
# [4027 rows x 7 columns]

# %% [markdown]
# scaling the dataframe

# %%
y=pd.DataFrame(y)
y
# Out:
#        Age
# 0     16.5
# 1      8.5
# 2     10.5
# 3     11.5
# 4      8.5
# ...    ...
# 4172  12.5
# 4173  11.5
# 4174  10.5
# 4175  11.5
# 4176  13.5
#
# [4027 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    lm=DecisionTreeRegressor()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=r2_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRS=i
print("best accuracy is",maxAccu,"on random state",maxRS)
# Out:
# best accuracy is 0.2498708286434973 on random state 58

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=58)

# %%
model=[DecisionTreeRegressor(),SVR(),LinearRegression(),KNeighborsRegressor()]
for a in model:
    a.fit(x_train,y_train)
    a.score(x_train,y_train)
    predm=a.predict(x_test)
    print('accuracy score of' ,a, 'is:')
    print(r2_score(y_test,predm))
    print('error:')
    print('Mean absolute error:',mean_absolute_error(y_test,predm))
    print('mean squared error:',mean_squared_error(y_test,predm))
    print('root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,predm)))
    print('\n')
# Out:
# accuracy score of DecisionTreeRegressor() is:
# 0.15695063728077363
# error:
# Mean absolute error: 1.9164785553047403
# mean squared error: 7.081264108352144
# root Mean Squared Error:  2.661064469033425
#
#
# accuracy score of SVR() is:
# 0.5516239186752572
# error:
# Mean absolute error: 1.4044016492102376
# mean squared error: 3.766172649116782
# root Mean Squared Error:  1.940662940625389
#
#
# accuracy score of LinearRegression() is:
# 0.5223067026603403
# error:
# Mean absolute error: 1.5117849331171762
# mean squared error: 4.01242507359359
# root Mean Squared Error:  2.0031038599118096
#
#
# accuracy score of KNeighborsRegressor() is:
# 0.5037519953571421
# error:
# Mean absolute error: 1.4996237772761474
# mean squared error: 4.168276899924755
# root Mean Squared Error:  2.0416358392046203

# %% [markdown]
# best score is for svr.

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(DecisionTreeRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.0866582  -0.55458559  0.07058387  0.0859628   0.10528592]
# -0.04121896138304739
# 0.25691890292914055

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(SVR(),x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.33954519 0.50523361 0.49677629 0.54914642 0.5658486 ]
# 0.49131001991838863
# 0.08019645571464447

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(LinearRegression(),x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.39008453 0.25757084 0.49430205 0.49302985 0.47281313]
# 0.42156008140273754
# 0.09045372103153183

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(KNeighborsRegressor(),x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.29144114 0.28493218 0.45257674 0.46532724 0.47169912]
# 0.39319528247797375
# 0.08598468976306994

# %% [markdown]
# best score.mean is of svr

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
parameter={'kernel':['linear','poly','sigmoid'],
         'gamma':['scale','auto'],
          'degree':np.arange(0,5),
          'C':np.arange(0,5)}

# %%
GCV=GridSearchCV(SVR(),parameter,cv=5,verbose=True,n_jobs=-1)

# %%
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': array([0, 1, 2, 3, 4]),
#                          'degree': array([0, 1, 2, 3, 4]),
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'sigmoid']},
#              verbose=True)

# %%
GCV.best_params_
# Out:
# {'C': 4, 'degree': 0, 'gamma': 'scale', 'kernel': 'linear'}

# %%
abalone_mod=SVR(gamma='scale',degree=0,kernel='linear',C=3)
abalone_mod.fit(x_train,y_train)
pred=abalone_mod.predict(x_test)
acc=r2_score(y_test,pred)
print(acc*100)
# Out:
# 51.78204792465958

# %% [markdown]
# after doing hyperparameter tuning svr is giving 51.39% accuracy.

# %%
from sklearn.ensemble import GradientBoostingRegressor
#GradientBoostingRegressor(base_estimator=Lasso(),n_estimators=50,learning_rate=1.0)
ad=GradientBoostingRegressor()
ad.fit(x_train,y_train)
pred_ad=ad.predict(x_test)
print(r2_score(y_test,pred_ad))
print('Mean absolute error:',mean_absolute_error(y_test,pred_ad))
print('mean squared error:',mean_squared_error(y_test,pred_ad))
print('root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_ad)))
# Out:
# 0.5593978702348024
# Mean absolute error: 1.4336248710177457
# mean squared error: 3.7008746884124215
# root Mean Squared Error:  1.9237657571576696

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100,random_state=42)
#randomforestclassifier(100)--> default
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(r2_score(y_test,predrf))
# Out:
# 0.5470379353437556

# %% [markdown]
# after doing the ensembe technique best model is given by random forest with 56.31%

# %%
import joblib
joblib.dump(rf,"abalonemodel.pkl")
# Out:
# ['abalonemodel.pkl']

# %% [markdown]
# saved the best model
